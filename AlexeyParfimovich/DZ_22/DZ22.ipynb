# %% [markdown]
# ## Группа DS03-onl
#
# Студент Парфимович Алексей
#
# ## Домашнее задание №22
#
# Рекомендательные системы.
#
# Изучить работу алгоритма Apriori на примере приложенного набора данных.
# Рассмотреть различные реализации алгоритма

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.metrics import mean_squared_error

# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (18, 5)

RANDOM_STATE = 42

# %% [markdown]
# Загрузить данные.

# %%
# Файл данных не содержит строки заголовков - отключим получение заголовоков из файла
df = pd.read_csv('dataset.csv', delimiter=',', header=None, skipinitialspace=True)

df.fillna('', inplace=True)
df.head()
# Out:
#         0              1           2             3             4           5   \
# 0     pork  sandwich bags  lunch meat  all- purpose         flour        soda
# 1  shampoo      hand soap     waffles    vegetables       cheeses       mixes
# 2     pork           soap   ice cream  toilet paper  dinner rolls   hand soap
# 3    juice     lunch meat        soda  toilet paper  all- purpose
# 4    pasta      tortillas       mixes     hand soap  toilet paper  vegetables
#
#                 6              7                  8   \
# 0           butter     vegetables               beef
# 1             milk  sandwich bags  laundry detergent
# 2  spaghetti sauce           milk            ketchup
# 3
# 4       vegetables   paper towels         vegetables
#
#                              9             10                11         12  \
# 0                 aluminum foil  all- purpose      dinner rolls    shampoo
# 1  dishwashing liquid/detergent       waffles  individual meals  hand soap
# 2               sandwich loaves       poultry      toilet paper  ice cream
# 3
# 4                         flour    vegetables              pork    poultry
#
#              13
# 0  all- purpose
# 1    vegetables
# 2       ketchup
# 3
# 4          eggs

# %%
basket = []
for i, row in df.iterrows():
    basket.append(row.loc[row != ''].to_list())

basket
# Out:
# [['pork',
#   'sandwich bags',
#   'lunch meat',
#   'all- purpose',
#   'flour',
#   'soda',
#   'butter',
#   'vegetables',
#   'beef',
#   'aluminum foil',
#   'all- purpose',
#   'dinner rolls',
#   'shampoo',
#   'all- purpose'],
#  ['shampoo',
#   'hand soap',
#   'waffles',
#   'vegetables',
#   'cheeses',
#   'mixes',
#   'milk',
#   'sandwich bags',
#   'laundry detergent',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'individual meals',
#   'hand soap',
#   'vegetables'],
#  ['pork',
#   'soap',
#   'ice cream',
#   'toilet paper',
#   'dinner rolls',
#   'hand soap',
#   'spaghetti sauce',
#   'milk',
#   'ketchup',
#   'sandwich loaves',
#   'poultry',
#   'toilet paper',
#   'ice cream',
#   'ketchup'],
#  ['juice', 'lunch meat', 'soda', 'toilet paper', 'all- purpose'],
#  ['pasta',
#   'tortillas',
#   'mixes',
#   'hand soap',
#   'toilet paper',
#   'vegetables',
#   'vegetables',
#   'paper towels',
#   'vegetables',
#   'flour',
#   'vegetables',
#   'pork',
#   'poultry',
#   'eggs'],
#  ['toilet paper',
#   'eggs',
#   'toilet paper',
#   'vegetables',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'cereals',
#   'paper towels',
#   'laundry detergent',
#   'butter',
#   'cereals',
#   'bagels',
#   'paper towels',
#   'shampoo'],
#  ['paper towels',
#   'tortillas',
#   'vegetables',
#   'milk',
#   'ice cream',
#   'juice',
#   'dishwashing liquid/detergent',
#   'soap',
#   'sandwich bags',
#   'pasta',
#   'ketchup',
#   'all- purpose',
#   'yogurt',
#   'mixes'],
#  ['juice',
#   'paper towels',
#   'waffles',
#   'soda',
#   'cheeses',
#   'poultry',
#   'toilet paper',
#   'vegetables'],
#  ['poultry', 'coffee/tea', 'coffee/tea', 'dishwashing liquid/detergent'],
#  ['coffee/tea',
#   'toilet paper',
#   'pork',
#   'flour',
#   'milk',
#   'soda',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'tortillas',
#   'tortillas',
#   'vegetables',
#   'fruits',
#   'sugar',
#   'soap'],
#  ['ice cream',
#   'soda',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'sugar',
#   'waffles',
#   'individual meals',
#   'toilet paper',
#   'pasta',
#   'sandwich loaves',
#   'cheeses',
#   'vegetables',
#   'hand soap'],
#  ['tortillas',
#   'pork',
#   'shampoo',
#   'lunch meat',
#   'pasta',
#   'juice',
#   'bagels',
#   'vegetables',
#   'bagels',
#   'vegetables',
#   'laundry detergent',
#   'yogurt',
#   'sugar',
#   'waffles'],
#  ['fruits',
#   'all- purpose',
#   'aluminum foil',
#   'laundry detergent',
#   'individual meals',
#   'flour',
#   'pork',
#   'shampoo',
#   'sugar',
#   'aluminum foil',
#   'shampoo',
#   'soap',
#   'bagels',
#   'toilet paper'],
#  ['dinner rolls',
#   'individual meals',
#   'shampoo',
#   'ketchup',
#   'cereals',
#   'sandwich bags',
#   'laundry detergent',
#   'vegetables',
#   'sandwich loaves',
#   'cheeses',
#   'vegetables'],
#  ['ice cream',
#   'cereals',
#   'paper towels',
#   'bagels',
#   'mixes',
#   'lunch meat',
#   'juice',
#   'toilet paper',
#   'cheeses',
#   'paper towels',
#   'paper towels',
#   'juice',
#   'aluminum foil',
#   'fruits'],
#  ['sandwich bags',
#   'flour',
#   'juice',
#   'milk',
#   'paper towels',
#   'cereals',
#   'sandwich bags',
#   'pasta',
#   'soda',
#   'dishwashing liquid/detergent',
#   'ice cream',
#   'soap',
#   'cheeses',
#   'beef'],
#  ['hand soap',
#   'pasta',
#   'individual meals',
#   'spaghetti sauce',
#   'cereals',
#   'sandwich loaves',
#   'hand soap',
#   'individual meals'],
#  ['toilet paper', 'bagels', 'shampoo', 'coffee/tea'],
#  ['laundry detergent',
#   'coffee/tea',
#   'eggs',
#   'aluminum foil',
#   'beef',
#   'juice',
#   'flour',
#   'sugar',
#   'individual meals',
#   'waffles',
#   'bagels',
#   'vegetables',
#   'coffee/tea',
#   'spaghetti sauce'],
#  ['dishwashing liquid/detergent',
#   'yogurt',
#   'juice',
#   'sugar',
#   'soap',
#   'sandwich loaves',
#   'butter',
#   'sandwich loaves',
#   'coffee/tea',
#   'ketchup',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'laundry detergent'],
#  ['fruits', 'all- purpose', 'pork', 'juice', 'bagels', 'mixes'],
#  ['vegetables', 'cereals', 'sugar', 'bagels', 'soda'],
#  ['vegetables',
#   'aluminum foil',
#   'bagels',
#   'vegetables',
#   'shampoo',
#   'shampoo',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'cereals',
#   'cheeses',
#   'flour',
#   'lunch meat',
#   'pasta',
#   'soda'],
#  ['all- purpose',
#   'pasta',
#   'cheeses',
#   'juice',
#   'sandwich bags',
#   'vegetables',
#   'sandwich loaves',
#   'coffee/tea',
#   'juice',
#   'lunch meat',
#   'spaghetti sauce',
#   'paper towels',
#   'hand soap',
#   'soap'],
#  ['sugar',
#   'pork',
#   'sandwich loaves',
#   'tortillas',
#   'ice cream',
#   'all- purpose',
#   'yogurt',
#   'fruits',
#   'pasta',
#   'lunch meat',
#   'dishwashing liquid/detergent',
#   'juice',
#   'vegetables',
#   'vegetables'],
#  ['sandwich loaves',
#   'vegetables',
#   'coffee/tea',
#   'aluminum foil',
#   'vegetables',
#   'shampoo',
#   'cereals',
#   'dinner rolls',
#   'coffee/tea',
#   'poultry',
#   'butter',
#   'juice',
#   'paper towels',
#   'vegetables'],
#  ['pork',
#   'pasta',
#   'cheeses',
#   'fruits',
#   'sugar',
#   'lunch meat',
#   'laundry detergent',
#   'paper towels',
#   'butter',
#   'sandwich loaves',
#   'ice cream',
#   'waffles',
#   'all- purpose',
#   'sandwich bags'],
#  ['bagels',
#   'poultry',
#   'pasta',
#   'butter',
#   'all- purpose',
#   'pasta',
#   'shampoo',
#   'sugar',
#   'ketchup',
#   'eggs',
#   'soda',
#   'tortillas',
#   'soap',
#   'individual meals'],
#  ['butter',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'juice',
#   'dinner rolls',
#   'all- purpose',
#   'pork',
#   'yogurt',
#   'vegetables',
#   'spaghetti sauce',
#   'vegetables'],
#  ['bagels', 'cheeses', 'sandwich loaves', 'toilet paper'],
#  ['eggs',
#   'ice cream',
#   'pasta',
#   'juice',
#   'waffles',
#   'shampoo',
#   'dinner rolls',
#   'soda',
#   'vegetables',
#   'laundry detergent',
#   'hand soap',
#   'waffles',
#   'cereals',
#   'vegetables'],
#  ['paper towels',
#   'individual meals',
#   'dinner rolls',
#   'vegetables',
#   'lunch meat',
#   'sugar',
#   'soap',
#   'eggs',
#   'beef',
#   'yogurt',
#   'soda',
#   'sandwich loaves',
#   'aluminum foil',
#   'dinner rolls'],
#  ['pork',
#   'sandwich bags',
#   'ketchup',
#   'coffee/tea',
#   'vegetables',
#   'soda',
#   'poultry',
#   'pasta',
#   'all- purpose',
#   'coffee/tea',
#   'paper towels',
#   'individual meals',
#   'vegetables',
#   'poultry'],
#  ['mixes',
#   'vegetables',
#   'soap',
#   'hand soap',
#   'tortillas',
#   'coffee/tea',
#   'cheeses',
#   'tortillas',
#   'cheeses',
#   'ice cream',
#   'tortillas',
#   'beef',
#   'yogurt',
#   'spaghetti sauce'],
#  ['cheeses',
#   'cereals',
#   'mixes',
#   'laundry detergent',
#   'juice',
#   'pork',
#   'bagels',
#   'sandwich loaves',
#   'yogurt',
#   'milk',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'cereals',
#   'individual meals'],
#  ['vegetables',
#   'lunch meat',
#   'flour',
#   'juice',
#   'yogurt',
#   'shampoo',
#   'spaghetti sauce',
#   'ketchup',
#   'laundry detergent',
#   'dinner rolls',
#   'ketchup',
#   'vegetables',
#   'shampoo',
#   'sugar'],
#  ['lunch meat',
#   'dinner rolls',
#   'shampoo',
#   'vegetables',
#   'hand soap',
#   'mixes',
#   'vegetables',
#   'pasta',
#   'sugar',
#   'vegetables'],
#  ['hand soap',
#   'dinner rolls',
#   'hand soap',
#   'lunch meat',
#   'laundry detergent',
#   'pasta',
#   'aluminum foil',
#   'toilet paper',
#   'cereals',
#   'coffee/tea',
#   'toilet paper',
#   'vegetables',
#   'juice',
#   'lunch meat'],
#  ['milk',
#   'dinner rolls',
#   'beef',
#   'coffee/tea',
#   'waffles',
#   'beef',
#   'eggs',
#   'sandwich bags',
#   'tortillas',
#   'vegetables',
#   'tortillas',
#   'all- purpose',
#   'vegetables',
#   'yogurt'],
#  ['sandwich bags',
#   'poultry',
#   'beef',
#   'coffee/tea',
#   'mixes',
#   'poultry',
#   'sandwich loaves',
#   'shampoo',
#   'ice cream',
#   'poultry',
#   'shampoo'],
#  ['hand soap',
#   'fruits',
#   'poultry',
#   'coffee/tea',
#   'sugar',
#   'tortillas',
#   'soda',
#   'individual meals',
#   'tortillas',
#   'milk',
#   'toilet paper',
#   'soda',
#   'poultry',
#   'coffee/tea'],
#  ['shampoo',
#   'waffles',
#   'bagels',
#   'mixes',
#   'shampoo',
#   'mixes',
#   'beef',
#   'dinner rolls',
#   'beef',
#   'shampoo',
#   'aluminum foil',
#   'individual meals',
#   'sugar',
#   'spaghetti sauce'],
#  ['butter',
#   'ketchup',
#   'shampoo',
#   'juice',
#   'mixes',
#   'milk',
#   'shampoo',
#   'tortillas',
#   'laundry detergent',
#   'flour',
#   'cereals',
#   'soap',
#   'toilet paper',
#   'butter'],
#  ['hand soap',
#   'waffles',
#   'laundry detergent',
#   'shampoo',
#   'lunch meat',
#   'cheeses',
#   'vegetables',
#   'hand soap',
#   'cereals',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'soda',
#   'spaghetti sauce',
#   'aluminum foil'],
#  ['cereals',
#   'toilet paper',
#   'waffles',
#   'soda',
#   'pork',
#   'yogurt',
#   'pork',
#   'all- purpose',
#   'toilet paper',
#   'vegetables',
#   'spaghetti sauce',
#   'toilet paper',
#   'vegetables',
#   'laundry detergent'],
#  ['spaghetti sauce',
#   'sandwich bags',
#   'ice cream',
#   'fruits',
#   'soap',
#   'cheeses',
#   'waffles',
#   'tortillas',
#   'sugar',
#   'toilet paper',
#   'ketchup',
#   'beef',
#   'beef',
#   'poultry'],
#  ['waffles',
#   'vegetables',
#   'beef',
#   'fruits',
#   'sandwich loaves',
#   'ketchup',
#   'cheeses',
#   'sugar',
#   'shampoo',
#   'butter',
#   'laundry detergent',
#   'poultry',
#   'waffles',
#   'soap'],
#  ['mixes',
#   'individual meals',
#   'laundry detergent',
#   'coffee/tea',
#   'hand soap',
#   'pasta',
#   'individual meals',
#   'cereals',
#   'spaghetti sauce',
#   'pasta',
#   'cereals',
#   'fruits',
#   'flour',
#   'vegetables'],
#  ['aluminum foil',
#   'sandwich bags',
#   'all- purpose',
#   'shampoo',
#   'beef',
#   'sandwich loaves',
#   'aluminum foil',
#   'ice cream',
#   'fruits',
#   'lunch meat',
#   'all- purpose',
#   'bagels',
#   'vegetables',
#   'sandwich loaves'],
#  ['cereals',
#   'beef',
#   'flour',
#   'sugar',
#   'beef',
#   'eggs',
#   'aluminum foil',
#   'vegetables',
#   'pork',
#   'soda',
#   'mixes',
#   'vegetables',
#   'ketchup',
#   'vegetables'],
#  ['sugar',
#   'pasta',
#   'sandwich loaves',
#   'mixes',
#   'butter',
#   'pasta',
#   'aluminum foil',
#   'tortillas',
#   'paper towels',
#   'yogurt',
#   'coffee/tea',
#   'sandwich bags',
#   'soda',
#   'poultry'],
#  ['cereals',
#   'mixes',
#   'cereals',
#   'pork',
#   'cheeses',
#   'poultry',
#   'all- purpose',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'beef',
#   'ketchup',
#   'mixes',
#   'ice cream'],
#  ['flour',
#   'butter',
#   'vegetables',
#   'lunch meat',
#   'toilet paper',
#   'tortillas',
#   'laundry detergent',
#   'milk',
#   'poultry',
#   'laundry detergent',
#   'milk',
#   'soda',
#   'butter',
#   'spaghetti sauce'],
#  ['butter',
#   'waffles',
#   'aluminum foil',
#   'coffee/tea',
#   'vegetables',
#   'vegetables',
#   'mixes',
#   'paper towels',
#   'juice',
#   'tortillas',
#   'dinner rolls',
#   'eggs',
#   'shampoo',
#   'waffles'],
#  ['tortillas',
#   'soda',
#   'beef',
#   'flour',
#   'eggs',
#   'vegetables',
#   'cheeses',
#   'lunch meat',
#   'coffee/tea',
#   'yogurt',
#   'dinner rolls',
#   'ice cream',
#   'pasta',
#   'fruits'],
#  ['poultry',
#   'eggs',
#   'eggs',
#   'ketchup',
#   'beef',
#   'toilet paper',
#   'soda',
#   'pork',
#   'ice cream',
#   'hand soap',
#   'shampoo',
#   'yogurt',
#   'fruits',
#   'waffles'],
#  ['spaghetti sauce',
#   'shampoo',
#   'ice cream',
#   'waffles',
#   'soda',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'soap',
#   'juice',
#   'all- purpose',
#   'vegetables',
#   'ketchup',
#   'individual meals',
#   'fruits'],
#  ['all- purpose',
#   'dishwashing liquid/detergent',
#   'soap',
#   'vegetables',
#   'milk',
#   'shampoo',
#   'coffee/tea',
#   'spaghetti sauce',
#   'aluminum foil',
#   'ice cream',
#   'pasta',
#   'all- purpose',
#   'eggs',
#   'tortillas'],
#  ['sandwich loaves',
#   'laundry detergent',
#   'ice cream',
#   'spaghetti sauce',
#   'milk',
#   'vegetables',
#   'all- purpose',
#   'cereals',
#   'hand soap',
#   'waffles',
#   'cereals',
#   'lunch meat',
#   'poultry',
#   'milk'],
#  ['flour',
#   'laundry detergent',
#   'poultry',
#   'milk',
#   'cheeses',
#   'pork',
#   'cereals',
#   'aluminum foil'],
#  ['fruits', 'all- purpose', 'juice', 'toilet paper'],
#  ['laundry detergent',
#   'laundry detergent',
#   'spaghetti sauce',
#   'beef',
#   'cheeses',
#   'shampoo',
#   'vegetables',
#   'waffles',
#   'cereals',
#   'sandwich bags',
#   'pasta',
#   'fruits',
#   'soap',
#   'vegetables'],
#  ['yogurt',
#   'ice cream',
#   'ice cream',
#   'toilet paper',
#   'ice cream',
#   'coffee/tea',
#   'sandwich bags',
#   'soda',
#   'ketchup',
#   'aluminum foil',
#   'all- purpose',
#   'pork',
#   'eggs',
#   'waffles'],
#  ['butter',
#   'flour',
#   'vegetables',
#   'bagels',
#   'sandwich bags',
#   'ice cream',
#   'sandwich loaves',
#   'flour',
#   'individual meals',
#   'ice cream',
#   'cheeses',
#   'milk',
#   'sandwich bags',
#   'poultry'],
#  ['hand soap',
#   'shampoo',
#   'beef',
#   'paper towels',
#   'mixes',
#   'lunch meat',
#   'pasta',
#   'shampoo',
#   'hand soap',
#   'pasta',
#   'milk',
#   'toilet paper',
#   'butter',
#   'eggs'],
#  ['hand soap',
#   'fruits',
#   'sandwich loaves',
#   'lunch meat',
#   'vegetables',
#   'individual meals',
#   'individual meals',
#   'sugar',
#   'fruits',
#   'cereals',
#   'ketchup',
#   'laundry detergent',
#   'cheeses',
#   'cheeses'],
#  ['cereals',
#   'yogurt',
#   'mixes',
#   'yogurt',
#   'sandwich loaves',
#   'hand soap',
#   'sugar',
#   'mixes',
#   'shampoo',
#   'all- purpose',
#   'pasta',
#   'cheeses',
#   'flour',
#   'poultry'],
#  ['lunch meat',
#   'sandwich bags',
#   'yogurt',
#   'ice cream',
#   'ice cream',
#   'individual meals',
#   'sugar',
#   'dishwashing liquid/detergent',
#   'flour',
#   'vegetables',
#   'paper towels',
#   'fruits',
#   'cheeses',
#   'vegetables'],
#  ['milk',
#   'yogurt',
#   'sugar',
#   'laundry detergent',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'cereals'],
#  ['soda', 'ketchup', 'poultry', 'vegetables'],
#  ['toilet paper',
#   'all- purpose',
#   'vegetables',
#   'juice',
#   'bagels',
#   'cheeses',
#   'fruits',
#   'vegetables',
#   'toilet paper',
#   'shampoo',
#   'eggs',
#   'butter',
#   'shampoo',
#   'butter'],
#  ['pasta',
#   'sugar',
#   'ketchup',
#   'waffles',
#   'all- purpose',
#   'vegetables',
#   'fruits',
#   'sandwich bags',
#   'sandwich bags',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'butter'],
#  ['ketchup',
#   'milk',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'butter',
#   'ice cream',
#   'laundry detergent',
#   'butter',
#   'aluminum foil',
#   'cereals',
#   'vegetables',
#   'spaghetti sauce',
#   'hand soap',
#   'mixes'],
#  ['vegetables',
#   'vegetables',
#   'ketchup',
#   'yogurt',
#   'cheeses',
#   'juice',
#   'all- purpose',
#   'mixes',
#   'ketchup',
#   'mixes',
#   'shampoo',
#   'milk',
#   'fruits',
#   'vegetables'],
#  ['individual meals',
#   'coffee/tea',
#   'lunch meat',
#   'butter',
#   'paper towels',
#   'pasta'],
#  ['laundry detergent',
#   'yogurt',
#   'toilet paper',
#   'tortillas',
#   'dinner rolls',
#   'tortillas',
#   'tortillas',
#   'soap',
#   'fruits',
#   'sandwich bags',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'milk',
#   'ketchup'],
#  ['dishwashing liquid/detergent',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'sugar',
#   'mixes',
#   'all- purpose',
#   'fruits',
#   'cereals',
#   'ice cream',
#   'lunch meat',
#   'sugar'],
#  ['dishwashing liquid/detergent',
#   'fruits',
#   'mixes',
#   'bagels',
#   'beef',
#   'ice cream',
#   'individual meals',
#   'bagels',
#   'butter'],
#  ['toilet paper',
#   'butter',
#   'lunch meat',
#   'individual meals',
#   'toilet paper',
#   'butter',
#   'poultry',
#   'cheeses',
#   'laundry detergent',
#   'spaghetti sauce',
#   'waffles',
#   'sandwich loaves'],
#  ['all- purpose',
#   'paper towels',
#   'ketchup',
#   'beef',
#   'soap',
#   'pork',
#   'waffles',
#   'lunch meat',
#   'cheeses',
#   'shampoo',
#   'spaghetti sauce',
#   'pork',
#   'poultry',
#   'all- purpose'],
#  ['vegetables',
#   'ketchup',
#   'soda',
#   'fruits',
#   'aluminum foil',
#   'yogurt',
#   'bagels',
#   'yogurt',
#   'milk',
#   'eggs',
#   'dishwashing liquid/detergent'],
#  ['soda',
#   'bagels',
#   'milk',
#   'fruits',
#   'pasta',
#   'spaghetti sauce',
#   'soap',
#   'cheeses',
#   'spaghetti sauce',
#   'juice',
#   'fruits',
#   'beef',
#   'toilet paper',
#   'dishwashing liquid/detergent'],
#  ['all- purpose',
#   'vegetables',
#   'individual meals',
#   'vegetables',
#   'toilet paper',
#   'pork',
#   'sandwich bags',
#   'paper towels',
#   'toilet paper',
#   'shampoo',
#   'coffee/tea',
#   'shampoo',
#   'juice',
#   'waffles'],
#  ['soap',
#   'cheeses',
#   'sandwich loaves',
#   'aluminum foil',
#   'bagels',
#   'tortillas',
#   'individual meals',
#   'hand soap',
#   'butter'],
#  ['aluminum foil',
#   'pork',
#   'fruits',
#   'sandwich bags',
#   'poultry',
#   'coffee/tea',
#   'bagels',
#   'hand soap',
#   'vegetables',
#   'mixes',
#   'ketchup',
#   'waffles',
#   'paper towels',
#   'tortillas'],
#  ['ketchup',
#   'all- purpose',
#   'beef',
#   'shampoo',
#   'sandwich loaves',
#   'coffee/tea',
#   'ketchup',
#   'vegetables',
#   'milk',
#   'butter',
#   'vegetables',
#   'pork',
#   'yogurt',
#   'vegetables'],
#  ['individual meals',
#   'shampoo',
#   'beef',
#   'sandwich bags',
#   'eggs',
#   'vegetables',
#   'shampoo',
#   'sandwich loaves',
#   'ketchup',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'beef',
#   'lunch meat',
#   'cereals'],
#  ['individual meals',
#   'sugar',
#   'spaghetti sauce',
#   'pasta',
#   'vegetables',
#   'cheeses',
#   'cheeses',
#   'fruits',
#   'fruits',
#   'lunch meat',
#   'vegetables',
#   'fruits',
#   'spaghetti sauce',
#   'individual meals'],
#  ['beef',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'juice',
#   'laundry detergent',
#   'beef',
#   'soda',
#   'laundry detergent',
#   'aluminum foil',
#   'soap'],
#  ['paper towels',
#   'individual meals',
#   'individual meals',
#   'aluminum foil',
#   'beef'],
#  ['cereals',
#   'sugar',
#   'tortillas',
#   'coffee/tea',
#   'sandwich loaves',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'dinner rolls',
#   'vegetables',
#   'mixes',
#   'all- purpose',
#   'ice cream'],
#  ['bagels',
#   'shampoo',
#   'sandwich bags',
#   'soap',
#   'ice cream',
#   'juice',
#   'shampoo',
#   'spaghetti sauce',
#   'vegetables',
#   'yogurt',
#   'ketchup'],
#  ['bagels',
#   'soda',
#   'vegetables',
#   'shampoo',
#   'vegetables',
#   'poultry',
#   'eggs',
#   'waffles',
#   'lunch meat',
#   'dinner rolls',
#   'beef',
#   'butter'],
#  ['tortillas',
#   'waffles',
#   'vegetables',
#   'pork',
#   'beef',
#   'mixes',
#   'vegetables',
#   'poultry',
#   'soap',
#   'toilet paper',
#   'waffles',
#   'vegetables',
#   'ketchup',
#   'poultry'],
#  ['ketchup',
#   'laundry detergent',
#   'pork',
#   'cheeses',
#   'shampoo',
#   'juice',
#   'yogurt',
#   'juice',
#   'eggs',
#   'coffee/tea',
#   'sandwich bags',
#   'flour',
#   'vegetables',
#   'beef'],
#  ['soap', 'pork', 'tortillas', 'soap'],
#  ['fruits',
#   'paper towels',
#   'sugar',
#   'individual meals',
#   'hand soap',
#   'milk',
#   'soda'],
#  ['coffee/tea',
#   'pork',
#   'aluminum foil',
#   'cheeses',
#   'soda',
#   'soda',
#   'bagels',
#   'vegetables'],
#  ['laundry detergent',
#   'juice',
#   'ketchup',
#   'cheeses',
#   'aluminum foil',
#   'waffles',
#   'pasta',
#   'vegetables',
#   'yogurt',
#   'eggs',
#   'aluminum foil',
#   'tortillas',
#   'toilet paper',
#   'paper towels'],
#  ['eggs',
#   'tortillas',
#   'vegetables',
#   'soda',
#   'vegetables',
#   'cereals',
#   'vegetables',
#   'mixes',
#   'toilet paper',
#   'bagels',
#   'dinner rolls'],
#  ['butter',
#   'cereals',
#   'cereals',
#   'vegetables',
#   'lunch meat',
#   'milk',
#   'milk',
#   'ice cream',
#   'butter',
#   'butter',
#   'poultry',
#   'paper towels',
#   'cheeses',
#   'lunch meat'],
#  ['cereals',
#   'lunch meat',
#   'sandwich loaves',
#   'vegetables',
#   'vegetables',
#   'pork',
#   'butter',
#   'poultry',
#   'soap',
#   'toilet paper'],
#  ['sandwich bags',
#   'flour',
#   'all- purpose',
#   'shampoo',
#   'coffee/tea',
#   'bagels',
#   'shampoo'],
#  ['dishwashing liquid/detergent',
#   'toilet paper',
#   'spaghetti sauce',
#   'mixes',
#   'all- purpose',
#   'cheeses',
#   'toilet paper',
#   'toilet paper',
#   'vegetables',
#   'coffee/tea',
#   'lunch meat',
#   'spaghetti sauce',
#   'flour',
#   'individual meals'],
#  ['cereals',
#   'ketchup',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'bagels',
#   'beef',
#   'eggs',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'individual meals',
#   'waffles',
#   'soap',
#   'milk',
#   'pork'],
#  ['cheeses',
#   'cereals',
#   'sugar',
#   'soap',
#   'hand soap',
#   'sugar',
#   'spaghetti sauce',
#   'milk',
#   'coffee/tea',
#   'aluminum foil',
#   'soda',
#   'cereals',
#   'ice cream',
#   'vegetables'],
#  ['ketchup',
#   'lunch meat',
#   'juice',
#   'waffles',
#   'sandwich loaves',
#   'vegetables',
#   'vegetables',
#   'cheeses',
#   'vegetables',
#   'pork',
#   'lunch meat',
#   'beef',
#   'tortillas',
#   'bagels'],
#  ['pasta',
#   'all- purpose',
#   'bagels',
#   'lunch meat',
#   'poultry',
#   'paper towels',
#   'coffee/tea',
#   'sugar',
#   'cereals',
#   'vegetables',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'bagels'],
#  ['poultry',
#   'vegetables',
#   'pork',
#   'vegetables',
#   'vegetables',
#   'vegetables',
#   'individual meals',
#   'hand soap',
#   'vegetables',
#   'hand soap',
#   'pasta',
#   'all- purpose',
#   'toilet paper',
#   'mixes'],
#  ['laundry detergent',
#   'cereals',
#   'toilet paper',
#   'sandwich bags',
#   'poultry',
#   'vegetables',
#   'ketchup',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'pork',
#   'flour',
#   'lunch meat',
#   'eggs'],
#  ['fruits',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'vegetables',
#   'waffles',
#   'poultry',
#   'soda',
#   'pork',
#   'sugar',
#   'poultry',
#   'flour',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'bagels'],
#  ['pork',
#   'aluminum foil',
#   'fruits',
#   'aluminum foil',
#   'cereals',
#   'lunch meat',
#   'coffee/tea',
#   'yogurt',
#   'bagels',
#   'sugar',
#   'sugar',
#   'eggs',
#   'sugar',
#   'fruits'],
#  ['sandwich loaves',
#   'vegetables',
#   'paper towels',
#   'vegetables',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'ketchup',
#   'soda',
#   'soda',
#   'sandwich bags',
#   'dinner rolls',
#   'all- purpose',
#   'ketchup',
#   'waffles'],
#  ['waffles',
#   'beef',
#   'individual meals',
#   'beef',
#   'shampoo',
#   'ice cream',
#   'cheeses',
#   'poultry',
#   'vegetables',
#   'dinner rolls',
#   'pasta',
#   'lunch meat',
#   'fruits',
#   'bagels'],
#  ['bagels',
#   'coffee/tea',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'cheeses',
#   'laundry detergent',
#   'hand soap'],
#  ['ice cream',
#   'shampoo',
#   'vegetables',
#   'milk',
#   'toilet paper',
#   'cereals',
#   'laundry detergent',
#   'dinner rolls',
#   'sugar',
#   'pork',
#   'flour',
#   'sugar'],
#  ['pasta',
#   'ketchup',
#   'sandwich bags',
#   'waffles',
#   'sugar',
#   'beef',
#   'pork',
#   'milk',
#   'ice cream',
#   'soda',
#   'fruits',
#   'cereals',
#   'vegetables',
#   'fruits'],
#  ['bagels',
#   'cheeses',
#   'soda',
#   'poultry',
#   'cheeses',
#   'vegetables',
#   'flour',
#   'dinner rolls',
#   'hand soap',
#   'laundry detergent',
#   'flour',
#   'vegetables',
#   'milk',
#   'dinner rolls'],
#  ['cheeses',
#   'yogurt',
#   'coffee/tea',
#   'coffee/tea',
#   'beef',
#   'toilet paper',
#   'shampoo',
#   'sandwich loaves',
#   'ketchup',
#   'sandwich loaves',
#   'paper towels',
#   'vegetables',
#   'vegetables',
#   'pork'],
#  ['paper towels',
#   'sugar',
#   'vegetables',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'shampoo'],
#  ['beef',
#   'beef',
#   'sugar',
#   'toilet paper',
#   'aluminum foil',
#   'aluminum foil',
#   'hand soap',
#   'all- purpose',
#   'yogurt',
#   'eggs',
#   'flour',
#   'fruits',
#   'waffles',
#   'waffles'],
#  ['juice',
#   'waffles',
#   'vegetables',
#   'waffles',
#   'lunch meat',
#   'spaghetti sauce',
#   'juice',
#   'all- purpose',
#   'flour',
#   'soap',
#   'waffles',
#   'juice',
#   'spaghetti sauce',
#   'vegetables'],
#  ['vegetables',
#   'soap',
#   'soda',
#   'cheeses',
#   'toilet paper',
#   'shampoo',
#   'eggs',
#   'paper towels',
#   'mixes',
#   'individual meals',
#   'coffee/tea',
#   'all- purpose',
#   'sugar',
#   'waffles'],
#  ['coffee/tea',
#   'sugar',
#   'cheeses',
#   'tortillas',
#   'all- purpose',
#   'milk',
#   'pasta',
#   'poultry',
#   'paper towels',
#   'yogurt',
#   'eggs',
#   'toilet paper',
#   'bagels',
#   'pork'],
#  ['cheeses',
#   'tortillas',
#   'spaghetti sauce',
#   'yogurt',
#   'beef',
#   'sandwich bags',
#   'laundry detergent',
#   'vegetables',
#   'soap',
#   'eggs',
#   'yogurt',
#   'juice',
#   'shampoo',
#   'vegetables'],
#  ['fruits',
#   'dinner rolls',
#   'vegetables',
#   'sandwich loaves',
#   'flour',
#   'eggs',
#   'pork',
#   'pork',
#   'spaghetti sauce',
#   'spaghetti sauce'],
#  ['butter',
#   'butter',
#   'poultry',
#   'beef',
#   'soap',
#   'fruits',
#   'vegetables',
#   'toilet paper',
#   'bagels',
#   'sugar',
#   'tortillas',
#   'poultry',
#   'toilet paper',
#   'fruits'],
#  ['soap',
#   'sandwich bags',
#   'ice cream',
#   'individual meals',
#   'ice cream',
#   'mixes',
#   'aluminum foil',
#   'bagels',
#   'sandwich bags',
#   'cereals',
#   'butter',
#   'beef',
#   'dishwashing liquid/detergent',
#   'laundry detergent'],
#  ['paper towels',
#   'spaghetti sauce',
#   'cereals',
#   'dinner rolls',
#   'tortillas',
#   'toilet paper',
#   'sugar'],
#  ['cereals',
#   'spaghetti sauce',
#   'lunch meat',
#   'fruits',
#   'spaghetti sauce',
#   'beef',
#   'shampoo',
#   'individual meals',
#   'paper towels',
#   'cheeses',
#   'aluminum foil',
#   'cheeses',
#   'coffee/tea',
#   'poultry'],
#  ['cheeses',
#   'aluminum foil',
#   'lunch meat',
#   'dinner rolls',
#   'sandwich bags',
#   'dinner rolls',
#   'flour',
#   'fruits',
#   'soda',
#   'aluminum foil',
#   'vegetables',
#   'eggs',
#   'mixes',
#   'sandwich bags'],
#  ['laundry detergent',
#   'laundry detergent',
#   'individual meals',
#   'poultry',
#   'juice',
#   'juice',
#   'lunch meat',
#   'sandwich bags',
#   'beef',
#   'dinner rolls',
#   'milk',
#   'toilet paper',
#   'pasta',
#   'ice cream'],
#  ['pork',
#   'mixes',
#   'flour',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'toilet paper',
#   'coffee/tea',
#   'soap',
#   'bagels',
#   'waffles',
#   'coffee/tea',
#   'pork',
#   'individual meals'],
#  ['pasta',
#   'eggs',
#   'cheeses',
#   'vegetables',
#   'all- purpose',
#   'ice cream',
#   'hand soap',
#   'shampoo',
#   'ice cream',
#   'vegetables',
#   'bagels',
#   'sandwich loaves',
#   'waffles',
#   'coffee/tea'],
#  ['juice',
#   'sugar',
#   'bagels',
#   'spaghetti sauce',
#   'ketchup',
#   'shampoo',
#   'tortillas',
#   'sandwich loaves',
#   'vegetables',
#   'flour',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'milk'],
#  ['eggs',
#   'ketchup',
#   'waffles',
#   'butter',
#   'sandwich loaves',
#   'sugar',
#   'sandwich bags',
#   'vegetables',
#   'shampoo',
#   'laundry detergent',
#   'sandwich bags',
#   'vegetables',
#   'cheeses',
#   'cereals'],
#  ['fruits',
#   'cheeses',
#   'waffles',
#   'vegetables',
#   'sandwich bags',
#   'aluminum foil',
#   'pasta',
#   'lunch meat',
#   'flour',
#   'butter',
#   'aluminum foil',
#   'poultry'],
#  ['tortillas',
#   'fruits',
#   'toilet paper',
#   'milk',
#   'butter',
#   'cereals',
#   'cereals',
#   'pasta',
#   'bagels',
#   'sandwich loaves',
#   'beef',
#   'cereals',
#   'aluminum foil',
#   'coffee/tea'],
#  ['laundry detergent',
#   'vegetables',
#   'ice cream',
#   'milk',
#   'sugar',
#   'mixes',
#   'vegetables',
#   'tortillas',
#   'toilet paper',
#   'milk',
#   'sandwich bags',
#   'poultry',
#   'soda',
#   'sandwich loaves'],
#  ['butter',
#   'cereals',
#   'soda',
#   'dishwashing liquid/detergent',
#   'cheeses',
#   'cheeses',
#   'sandwich loaves',
#   'flour',
#   'hand soap',
#   'cereals',
#   'individual meals'],
#  ['bagels', 'aluminum foil', 'beef', 'flour', 'spaghetti sauce', 'vegetables'],
#  ['pasta',
#   'butter',
#   'vegetables',
#   'dinner rolls',
#   'all- purpose',
#   'ketchup',
#   'cereals',
#   'ice cream',
#   'toilet paper',
#   'spaghetti sauce'],
#  ['pasta',
#   'yogurt',
#   'waffles',
#   'vegetables',
#   'waffles',
#   'mixes',
#   'cereals',
#   'eggs',
#   'soda',
#   'spaghetti sauce',
#   'mixes',
#   'dinner rolls',
#   'pasta'],
#  ['bagels',
#   'aluminum foil',
#   'flour',
#   'individual meals',
#   'dinner rolls',
#   'ketchup',
#   'tortillas',
#   'butter',
#   'aluminum foil',
#   'paper towels',
#   'toilet paper',
#   'laundry detergent',
#   'dinner rolls',
#   'vegetables'],
#  ['pasta',
#   'fruits',
#   'aluminum foil',
#   'hand soap',
#   'vegetables',
#   'all- purpose',
#   'flour'],
#  ['pork',
#   'hand soap',
#   'vegetables',
#   'ketchup',
#   'yogurt',
#   'butter',
#   'ice cream',
#   'lunch meat',
#   'laundry detergent',
#   'lunch meat',
#   'butter',
#   'yogurt',
#   'all- purpose',
#   'waffles'],
#  ['vegetables',
#   'juice',
#   'cereals',
#   'pork',
#   'poultry',
#   'sugar',
#   'vegetables',
#   'shampoo',
#   'yogurt',
#   'soap'],
#  ['individual meals',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'cereals',
#   'milk',
#   'paper towels',
#   'lunch meat',
#   'vegetables',
#   'sugar',
#   'beef',
#   'toilet paper',
#   'spaghetti sauce'],
#  ['ketchup',
#   'milk',
#   'all- purpose',
#   'mixes',
#   'cheeses',
#   'individual meals',
#   'yogurt',
#   'yogurt',
#   'paper towels',
#   'vegetables',
#   'pork',
#   'shampoo',
#   'pork',
#   'sugar'],
#  ['ice cream',
#   'butter',
#   'ketchup',
#   'ketchup',
#   'vegetables',
#   'pasta',
#   'sugar',
#   'eggs',
#   'sandwich loaves',
#   'individual meals',
#   'spaghetti sauce',
#   'dinner rolls',
#   'aluminum foil',
#   'eggs'],
#  ['ketchup',
#   'cheeses',
#   'individual meals',
#   'spaghetti sauce',
#   'dishwashing liquid/detergent',
#   'soap',
#   'all- purpose',
#   'fruits',
#   'eggs',
#   'bagels',
#   'beef',
#   'waffles',
#   'sandwich loaves',
#   'vegetables'],
#  ['spaghetti sauce',
#   'paper towels',
#   'soap',
#   'eggs',
#   'mixes',
#   'coffee/tea',
#   'tortillas',
#   'eggs',
#   'waffles',
#   'laundry detergent'],
#  ['soda',
#   'spaghetti sauce',
#   'fruits',
#   'beef',
#   'lunch meat',
#   'sugar',
#   'yogurt',
#   'aluminum foil',
#   'vegetables',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'eggs',
#   'dishwashing liquid/detergent'],
#  ['pasta',
#   'vegetables',
#   'sugar',
#   'pasta',
#   'sugar',
#   'bagels',
#   'milk',
#   'coffee/tea',
#   'flour',
#   'dinner rolls',
#   'aluminum foil',
#   'vegetables',
#   'ketchup',
#   'aluminum foil'],
#  ['cereals', 'sandwich bags', 'juice', 'tortillas', 'spaghetti sauce'],
#  ['juice',
#   'poultry',
#   'sandwich bags',
#   'individual meals',
#   'shampoo',
#   'yogurt',
#   'fruits',
#   'coffee/tea',
#   'vegetables',
#   'ice cream',
#   'poultry',
#   'pork',
#   'coffee/tea',
#   'vegetables'],
#  ['all- purpose',
#   'coffee/tea',
#   'vegetables',
#   'eggs',
#   'beef',
#   'juice',
#   'bagels',
#   'vegetables',
#   'fruits',
#   'juice',
#   'vegetables',
#   'hand soap',
#   'flour',
#   'sugar'],
#  ['eggs',
#   'sandwich bags',
#   'cereals',
#   'hand soap',
#   'pasta',
#   'laundry detergent',
#   'poultry',
#   'eggs',
#   'pork',
#   'pasta',
#   'laundry detergent'],
#  ['bagels',
#   'vegetables',
#   'toilet paper',
#   'cereals',
#   'sugar',
#   'laundry detergent',
#   'fruits',
#   'butter',
#   'dinner rolls',
#   'ice cream',
#   'bagels',
#   'ketchup'],
#  ['yogurt',
#   'toilet paper',
#   'coffee/tea',
#   'mixes',
#   'milk',
#   'soda',
#   'milk',
#   'cereals'],
#  ['pork',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'fruits',
#   'cheeses',
#   'toilet paper',
#   'coffee/tea',
#   'vegetables',
#   'yogurt',
#   'dinner rolls',
#   'milk',
#   'poultry',
#   'cheeses'],
#  ['sandwich bags',
#   'coffee/tea',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'soap',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'ketchup',
#   'beef',
#   'spaghetti sauce',
#   'fruits',
#   'sandwich bags',
#   'sandwich bags',
#   'cheeses'],
#  ['coffee/tea', 'ice cream', 'bagels', 'pork'],
#  ['all- purpose',
#   'ketchup',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'sugar',
#   'eggs',
#   'waffles',
#   'juice',
#   'dishwashing liquid/detergent',
#   'flour',
#   'eggs',
#   'all- purpose',
#   'flour',
#   'sandwich bags'],
#  ['tortillas',
#   'vegetables',
#   'milk',
#   'hand soap',
#   'fruits',
#   'coffee/tea',
#   'sugar',
#   'pork'],
#  ['fruits',
#   'aluminum foil',
#   'bagels',
#   'eggs',
#   'flour',
#   'cheeses',
#   'paper towels',
#   'shampoo',
#   'aluminum foil',
#   'vegetables',
#   'coffee/tea',
#   'spaghetti sauce',
#   'juice',
#   'bagels'],
#  ['dinner rolls',
#   'soda',
#   'dinner rolls',
#   'dinner rolls',
#   'hand soap',
#   'dinner rolls',
#   'all- purpose',
#   'tortillas',
#   'sugar',
#   'individual meals',
#   'bagels',
#   'soap',
#   'ketchup',
#   'individual meals'],
#  ['yogurt', 'all- purpose', 'mixes', 'bagels'],
#  ['hand soap',
#   'laundry detergent',
#   'yogurt',
#   'aluminum foil',
#   'bagels',
#   'fruits',
#   'mixes',
#   'mixes',
#   'soda',
#   'sandwich bags',
#   'vegetables'],
#  ['butter', 'ice cream', 'individual meals', 'all- purpose'],
#  ['pasta',
#   'poultry',
#   'cereals',
#   'soap',
#   'laundry detergent',
#   'pasta',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'paper towels',
#   'toilet paper',
#   'lunch meat',
#   'fruits',
#   'pork'],
#  ['eggs',
#   'dinner rolls',
#   'soap',
#   'individual meals',
#   'all- purpose',
#   'fruits',
#   'dinner rolls',
#   'laundry detergent',
#   'juice',
#   'dishwashing liquid/detergent',
#   'vegetables'],
#  ['vegetables',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'eggs',
#   'vegetables',
#   'soda',
#   'juice',
#   'sugar',
#   'ice cream',
#   'soap',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'individual meals',
#   'coffee/tea'],
#  ['beef',
#   'beef',
#   'mixes',
#   'vegetables',
#   'bagels',
#   'shampoo',
#   'milk',
#   'shampoo',
#   'flour',
#   'lunch meat',
#   'pork',
#   'yogurt',
#   'poultry',
#   'beef'],
#  ['mixes',
#   'pork',
#   'ice cream',
#   'juice',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'vegetables',
#   'butter',
#   'toilet paper',
#   'mixes',
#   'juice',
#   'paper towels',
#   'sandwich loaves',
#   'dishwashing liquid/detergent'],
#  ['cheeses',
#   'ketchup',
#   'flour',
#   'mixes',
#   'tortillas',
#   'shampoo',
#   'sandwich loaves',
#   'fruits',
#   'spaghetti sauce',
#   'lunch meat',
#   'lunch meat',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'yogurt'],
#  ['waffles',
#   'mixes',
#   'shampoo',
#   'laundry detergent',
#   'ketchup',
#   'paper towels',
#   'dinner rolls',
#   'ketchup',
#   'aluminum foil'],
#  ['fruits', 'pork', 'flour', 'cheeses', 'yogurt', 'juice', 'lunch meat'],
#  ['ketchup',
#   'vegetables',
#   'toilet paper',
#   'tortillas',
#   'juice',
#   'ketchup',
#   'spaghetti sauce',
#   'all- purpose',
#   'lunch meat',
#   'mixes',
#   'spaghetti sauce',
#   'ice cream',
#   'cheeses',
#   'paper towels'],
#  ['vegetables',
#   'paper towels',
#   'shampoo',
#   'fruits',
#   'yogurt',
#   'dinner rolls',
#   'lunch meat',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'toilet paper',
#   'mixes',
#   'soda',
#   'laundry detergent'],
#  ['vegetables', 'hand soap', 'milk', 'hand soap', 'beef'],
#  ['aluminum foil',
#   'sandwich bags',
#   'mixes',
#   'dinner rolls',
#   'milk',
#   'tortillas',
#   'milk',
#   'fruits',
#   'pasta',
#   'pasta',
#   'lunch meat',
#   'yogurt',
#   'cheeses',
#   'vegetables'],
#  ['toilet paper',
#   'juice',
#   'aluminum foil',
#   'all- purpose',
#   'beef',
#   'juice',
#   'paper towels',
#   'coffee/tea',
#   'individual meals'],
#  ['individual meals',
#   'eggs',
#   'ice cream',
#   'bagels',
#   'vegetables',
#   'poultry',
#   'dinner rolls',
#   'vegetables',
#   'butter',
#   'mixes',
#   'tortillas',
#   'spaghetti sauce',
#   'cereals',
#   'tortillas'],
#  ['waffles',
#   'flour',
#   'lunch meat',
#   'milk',
#   'tortillas',
#   'sandwich loaves',
#   'yogurt',
#   'flour',
#   'beef',
#   'shampoo',
#   'cereals',
#   'vegetables',
#   'waffles',
#   'aluminum foil'],
#  ['beef',
#   'pork',
#   'aluminum foil',
#   'sandwich bags',
#   'soda',
#   'beef',
#   'toilet paper',
#   'poultry',
#   'soap',
#   'pasta',
#   'ketchup'],
#  ['flour',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'ketchup',
#   'ketchup',
#   'bagels',
#   'all- purpose',
#   'hand soap',
#   'shampoo',
#   'yogurt',
#   'hand soap',
#   'poultry',
#   'vegetables',
#   'aluminum foil'],
#  ['cheeses',
#   'sandwich bags',
#   'cereals',
#   'laundry detergent',
#   'aluminum foil',
#   'yogurt',
#   'all- purpose',
#   'bagels',
#   'shampoo',
#   'soap',
#   'pasta',
#   'yogurt',
#   'lunch meat',
#   'vegetables'],
#  ['beef',
#   'dinner rolls',
#   'ketchup',
#   'pasta',
#   'milk',
#   'soap',
#   'hand soap',
#   'coffee/tea',
#   'hand soap',
#   'vegetables',
#   'ice cream',
#   'eggs',
#   'bagels',
#   'flour'],
#  ['beef',
#   'cheeses',
#   'ice cream',
#   'hand soap',
#   'laundry detergent',
#   'ketchup',
#   'juice',
#   'lunch meat',
#   'butter',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables'],
#  ['waffles',
#   'milk',
#   'laundry detergent',
#   'vegetables',
#   'dinner rolls',
#   'vegetables',
#   'milk',
#   'spaghetti sauce',
#   'toilet paper',
#   'pork',
#   'sugar',
#   'lunch meat',
#   'toilet paper',
#   'sandwich loaves'],
#  ['flour',
#   'individual meals',
#   'flour',
#   'poultry',
#   'butter',
#   'hand soap',
#   'eggs',
#   'butter',
#   'flour',
#   'butter',
#   'ketchup',
#   'laundry detergent',
#   'spaghetti sauce',
#   'shampoo'],
#  ['soap',
#   'dinner rolls',
#   'ice cream',
#   'sandwich loaves',
#   'toilet paper',
#   'sandwich bags',
#   'juice',
#   'ketchup',
#   'beef',
#   'cheeses',
#   'soap',
#   'paper towels'],
#  ['pork',
#   'sugar',
#   'sandwich bags',
#   'pasta',
#   'ketchup',
#   'sandwich bags',
#   'pork',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'milk',
#   'bagels'],
#  ['ketchup',
#   'pasta',
#   'tortillas',
#   'sandwich loaves',
#   'laundry detergent',
#   'soap'],
#  ['milk',
#   'flour',
#   'beef',
#   'soda',
#   'sandwich loaves',
#   'ice cream',
#   'fruits',
#   'ice cream',
#   'fruits',
#   'soda',
#   'all- purpose'],
#  ['ice cream',
#   'bagels',
#   'pork',
#   'all- purpose',
#   'ice cream',
#   'ice cream',
#   'vegetables',
#   'pasta',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'ice cream',
#   'hand soap',
#   'soap',
#   'butter'],
#  ['individual meals',
#   'paper towels',
#   'mixes',
#   'ketchup',
#   'aluminum foil',
#   'juice',
#   'spaghetti sauce',
#   'fruits'],
#  ['pasta',
#   'dinner rolls',
#   'aluminum foil',
#   'sandwich loaves',
#   'ice cream',
#   'vegetables',
#   'butter',
#   'cereals',
#   'butter',
#   'beef',
#   'soda',
#   'toilet paper',
#   'cheeses',
#   'waffles'],
#  ['coffee/tea',
#   'pasta',
#   'aluminum foil',
#   'lunch meat',
#   'sandwich loaves',
#   'sandwich bags',
#   'sugar',
#   'aluminum foil',
#   'tortillas',
#   'individual meals',
#   'juice',
#   'vegetables'],
#  ['all- purpose',
#   'vegetables',
#   'paper towels',
#   'fruits',
#   'poultry',
#   'poultry',
#   'mixes',
#   'vegetables',
#   'soda',
#   'milk',
#   'individual meals',
#   'sugar',
#   'yogurt'],
#  ['dinner rolls',
#   'milk',
#   'tortillas',
#   'ice cream',
#   'vegetables',
#   'dinner rolls',
#   'poultry',
#   'vegetables',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'cereals',
#   'butter',
#   'hand soap'],
#  ['spaghetti sauce',
#   'sandwich loaves',
#   'flour',
#   'soap',
#   'vegetables',
#   'eggs',
#   'vegetables',
#   'poultry',
#   'cereals',
#   'cheeses',
#   'fruits',
#   'vegetables',
#   'paper towels',
#   'flour'],
#  ['milk',
#   'vegetables',
#   'dinner rolls',
#   'butter',
#   'all- purpose',
#   'sandwich loaves',
#   'waffles',
#   'yogurt',
#   'vegetables',
#   'coffee/tea',
#   'flour',
#   'bagels',
#   'vegetables',
#   'lunch meat'],
#  ['beef',
#   'lunch meat',
#   'beef',
#   'mixes',
#   'individual meals',
#   'milk',
#   'shampoo',
#   'all- purpose',
#   'yogurt',
#   'individual meals',
#   'spaghetti sauce',
#   'paper towels',
#   'cereals',
#   'aluminum foil'],
#  ['vegetables',
#   'dinner rolls',
#   'sugar',
#   'bagels',
#   'spaghetti sauce',
#   'dishwashing liquid/detergent'],
#  ['coffee/tea',
#   'eggs',
#   'toilet paper',
#   'dinner rolls',
#   'pasta',
#   'paper towels',
#   'tortillas',
#   'spaghetti sauce',
#   'waffles',
#   'all- purpose',
#   'bagels',
#   'aluminum foil',
#   'bagels',
#   'soda'],
#  ['hand soap', 'sandwich bags', 'milk', 'milk'],
#  ['shampoo',
#   'eggs',
#   'beef',
#   'ice cream',
#   'paper towels',
#   'shampoo',
#   'individual meals',
#   'shampoo',
#   'pasta',
#   'milk',
#   'coffee/tea',
#   'pasta',
#   'waffles',
#   'pasta'],
#  ['poultry',
#   'waffles',
#   'aluminum foil',
#   'coffee/tea',
#   'toilet paper',
#   'hand soap',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'aluminum foil',
#   'pork',
#   'spaghetti sauce',
#   'beef',
#   'dinner rolls'],
#  ['hand soap',
#   'eggs',
#   'soda',
#   'aluminum foil',
#   'poultry',
#   'tortillas',
#   'bagels',
#   'vegetables',
#   'sandwich bags',
#   'cheeses',
#   'sandwich bags',
#   'cereals',
#   'mixes',
#   'dinner rolls'],
#  ['spaghetti sauce',
#   'tortillas',
#   'spaghetti sauce',
#   'vegetables',
#   'soda',
#   'spaghetti sauce',
#   'pasta',
#   'sandwich bags',
#   'spaghetti sauce',
#   'yogurt',
#   'bagels',
#   'toilet paper',
#   'shampoo',
#   'vegetables'],
#  ['bagels', 'sandwich loaves', 'butter', 'vegetables'],
#  ['dinner rolls',
#   'pasta',
#   'soap',
#   'ketchup',
#   'paper towels',
#   'vegetables',
#   'juice',
#   'sugar',
#   'ice cream',
#   'sandwich bags',
#   'spaghetti sauce'],
#  ['spaghetti sauce',
#   'paper towels',
#   'individual meals',
#   'poultry',
#   'soap',
#   'ice cream',
#   'paper towels',
#   'ice cream',
#   'coffee/tea',
#   'soap',
#   'milk',
#   'soap',
#   'eggs',
#   'cereals'],
#  ['waffles',
#   'shampoo',
#   'mixes',
#   'vegetables',
#   'shampoo',
#   'flour',
#   'waffles',
#   'soda',
#   'sandwich loaves',
#   'vegetables',
#   'sandwich loaves',
#   'soap',
#   'laundry detergent',
#   'vegetables'],
#  ['sugar',
#   'coffee/tea',
#   'all- purpose',
#   'juice',
#   'mixes',
#   'soda',
#   'yogurt',
#   'vegetables',
#   'all- purpose',
#   'cereals',
#   'soap',
#   'soda',
#   'hand soap',
#   'vegetables'],
#  ['individual meals',
#   'juice',
#   'individual meals',
#   'vegetables',
#   'vegetables',
#   'sugar'],
#  ['bagels',
#   'spaghetti sauce',
#   'beef',
#   'sandwich loaves',
#   'fruits',
#   'laundry detergent',
#   'ice cream',
#   'cereals',
#   'lunch meat',
#   'poultry',
#   'bagels',
#   'all- purpose',
#   'paper towels',
#   'pasta'],
#  ['juice',
#   'dishwashing liquid/detergent',
#   'milk',
#   'individual meals',
#   'spaghetti sauce',
#   'toilet paper',
#   'flour',
#   'yogurt',
#   'waffles',
#   'tortillas',
#   'fruits',
#   'paper towels',
#   'cereals',
#   'pasta'],
#  ['pasta',
#   'eggs',
#   'shampoo',
#   'sugar',
#   'paper towels',
#   'ketchup',
#   'poultry',
#   'sugar',
#   'soda',
#   'butter',
#   'paper towels',
#   'pasta',
#   'waffles',
#   'lunch meat'],
#  ['cheeses',
#   'butter',
#   'aluminum foil',
#   'vegetables',
#   'vegetables',
#   'poultry',
#   'hand soap',
#   'toilet paper',
#   'ice cream',
#   'sugar',
#   'mixes',
#   'vegetables',
#   'vegetables',
#   'milk'],
#  ['butter',
#   'spaghetti sauce',
#   'hand soap',
#   'soap',
#   'sandwich bags',
#   'ketchup',
#   'ice cream',
#   'waffles',
#   'flour',
#   'pasta',
#   'soap',
#   'pasta',
#   'all- purpose',
#   'dishwashing liquid/detergent'],
#  ['bagels', 'fruits', 'mixes', 'vegetables', 'tortillas', 'cereals'],
#  ['milk',
#   'bagels',
#   'pork',
#   'yogurt',
#   'ice cream',
#   'eggs',
#   'individual meals',
#   'soda',
#   'vegetables',
#   'pasta',
#   'pork',
#   'waffles',
#   'waffles',
#   'pork'],
#  ['fruits',
#   'spaghetti sauce',
#   'pasta',
#   'mixes',
#   'pasta',
#   'fruits',
#   'dishwashing liquid/detergent',
#   'juice',
#   'aluminum foil',
#   'flour',
#   'individual meals',
#   'yogurt',
#   'ketchup',
#   'fruits'],
#  ['eggs',
#   'cheeses',
#   'cereals',
#   'juice',
#   'hand soap',
#   'soap',
#   'soap',
#   'yogurt',
#   'pork',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'beef',
#   'bagels'],
#  ['butter',
#   'all- purpose',
#   'dinner rolls',
#   'vegetables',
#   'beef',
#   'vegetables',
#   'milk',
#   'laundry detergent'],
#  ['soda',
#   'bagels',
#   'poultry',
#   'vegetables',
#   'tortillas',
#   'milk',
#   'soap',
#   'yogurt',
#   'lunch meat',
#   'lunch meat',
#   'lunch meat'],
#  ['individual meals',
#   'poultry',
#   'individual meals',
#   'soda',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'pork',
#   'coffee/tea',
#   'hand soap',
#   'beef',
#   'ice cream',
#   'dinner rolls',
#   'lunch meat',
#   'individual meals'],
#  ['pasta',
#   'cereals',
#   'individual meals',
#   'vegetables',
#   'toilet paper',
#   'coffee/tea',
#   'toilet paper',
#   'mixes',
#   'fruits',
#   'vegetables',
#   'shampoo',
#   'soap',
#   'toilet paper',
#   'soap'],
#  ['sandwich loaves',
#   'eggs',
#   'soap',
#   'pasta',
#   'vegetables',
#   'dinner rolls',
#   'paper towels',
#   'soda',
#   'coffee/tea',
#   'poultry',
#   'cheeses',
#   'vegetables',
#   'spaghetti sauce',
#   'butter'],
#  ['juice', 'cereals', 'lunch meat', 'waffles', 'ketchup', 'pasta', 'juice'],
#  ['beef',
#   'sandwich bags',
#   'shampoo',
#   'fruits',
#   'cheeses',
#   'flour',
#   'laundry detergent',
#   'waffles',
#   'vegetables',
#   'soap',
#   'waffles',
#   'eggs',
#   'individual meals',
#   'eggs'],
#  ['spaghetti sauce',
#   'flour',
#   'milk',
#   'beef',
#   'laundry detergent',
#   'tortillas',
#   'cereals',
#   'coffee/tea',
#   'sandwich loaves',
#   'beef',
#   'toilet paper',
#   'milk',
#   'yogurt',
#   'soda'],
#  ['individual meals',
#   'lunch meat',
#   'soda',
#   'vegetables',
#   'sugar',
#   'mixes',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'bagels',
#   'coffee/tea',
#   'hand soap',
#   'sugar',
#   'spaghetti sauce'],
#  ['sugar',
#   'yogurt',
#   'butter',
#   'milk',
#   'poultry',
#   'hand soap',
#   'mixes',
#   'bagels',
#   'tortillas',
#   'vegetables',
#   'spaghetti sauce',
#   'flour',
#   'eggs',
#   'poultry'],
#  ['lunch meat',
#   'pasta',
#   'laundry detergent',
#   'sandwich loaves',
#   'vegetables',
#   'poultry',
#   'yogurt',
#   'laundry detergent',
#   'sandwich bags',
#   'aluminum foil',
#   'vegetables',
#   'tortillas',
#   'milk',
#   'soap'],
#  ['sandwich loaves',
#   'toilet paper',
#   'yogurt',
#   'fruits',
#   'butter',
#   'cereals',
#   'vegetables',
#   'waffles',
#   'beef',
#   'lunch meat',
#   'paper towels',
#   'mixes',
#   'paper towels',
#   'dinner rolls'],
#  ['waffles',
#   'juice',
#   'lunch meat',
#   'vegetables',
#   'shampoo',
#   'dinner rolls',
#   'all- purpose',
#   'sandwich loaves',
#   'hand soap',
#   'waffles',
#   'spaghetti sauce',
#   'shampoo',
#   'fruits',
#   'eggs'],
#  ['flour',
#   'waffles',
#   'soap',
#   'vegetables',
#   'tortillas',
#   'fruits',
#   'sugar',
#   'paper towels',
#   'lunch meat',
#   'lunch meat',
#   'spaghetti sauce',
#   'poultry'],
#  ['vegetables',
#   'flour',
#   'milk',
#   'soda',
#   'laundry detergent',
#   'yogurt',
#   'cheeses',
#   'yogurt'],
#  ['butter', 'poultry', 'aluminum foil', 'vegetables'],
#  ['yogurt',
#   'cereals',
#   'sandwich bags',
#   'laundry detergent',
#   'fruits',
#   'flour',
#   'soda',
#   'sandwich loaves',
#   'fruits',
#   'aluminum foil',
#   'individual meals',
#   'coffee/tea',
#   'spaghetti sauce',
#   'mixes'],
#  ['dinner rolls',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'eggs',
#   'pasta',
#   'ice cream',
#   'ketchup',
#   'sugar',
#   'flour',
#   'pasta',
#   'all- purpose',
#   'yogurt',
#   'pork',
#   'cereals'],
#  ['bagels',
#   'juice',
#   'cereals',
#   'mixes',
#   'fruits',
#   'individual meals',
#   'aluminum foil',
#   'sandwich loaves',
#   'laundry detergent',
#   'paper towels',
#   'all- purpose',
#   'ice cream',
#   'cereals',
#   'soap'],
#  ['pork',
#   'beef',
#   'vegetables',
#   'coffee/tea',
#   'cheeses',
#   'butter',
#   'bagels',
#   'waffles'],
#  ['soda', 'beef', 'juice', 'sugar'],
#  ['fruits',
#   'individual meals',
#   'vegetables',
#   'spaghetti sauce',
#   'hand soap',
#   'sandwich loaves',
#   'vegetables',
#   'sugar',
#   'pork',
#   'laundry detergent',
#   'sandwich loaves',
#   'dishwashing liquid/detergent',
#   'yogurt',
#   'bagels'],
#  ['sandwich loaves',
#   'bagels',
#   'pasta',
#   'toilet paper',
#   'ketchup',
#   'shampoo',
#   'beef',
#   'poultry',
#   'milk',
#   'beef',
#   'laundry detergent',
#   'juice',
#   'sugar',
#   'all- purpose'],
#  ['soap',
#   'yogurt',
#   'sandwich loaves',
#   'waffles',
#   'hand soap',
#   'poultry',
#   'toilet paper',
#   'toilet paper'],
#  ['spaghetti sauce',
#   'sandwich bags',
#   'ice cream',
#   'yogurt',
#   'bagels',
#   'tortillas',
#   'all- purpose',
#   'sandwich bags',
#   'ice cream',
#   'eggs',
#   'individual meals',
#   'butter',
#   'mixes',
#   'all- purpose'],
#  ['hand soap',
#   'ice cream',
#   'vegetables',
#   'bagels',
#   'milk',
#   'aluminum foil',
#   'dinner rolls',
#   'toilet paper',
#   'yogurt',
#   'ketchup',
#   'bagels',
#   'pasta',
#   'soap',
#   'beef'],
#  ['sugar',
#   'mixes',
#   'vegetables',
#   'poultry',
#   'waffles',
#   'pork',
#   'sandwich bags',
#   'toilet paper',
#   'all- purpose',
#   'tortillas',
#   'dinner rolls',
#   'hand soap'],
#  ['eggs',
#   'mixes',
#   'lunch meat',
#   'fruits',
#   'coffee/tea',
#   'yogurt',
#   'aluminum foil',
#   'flour'],
#  ['poultry',
#   'soap',
#   'butter',
#   'sandwich bags',
#   'beef',
#   'milk',
#   'all- purpose',
#   'pasta',
#   'dinner rolls'],
#  ['bagels',
#   'tortillas',
#   'dinner rolls',
#   'flour',
#   'vegetables',
#   'ketchup',
#   'juice',
#   'toilet paper',
#   'milk',
#   'all- purpose',
#   'spaghetti sauce',
#   'shampoo',
#   'spaghetti sauce',
#   'hand soap'],
#  ['waffles',
#   'laundry detergent',
#   'pasta',
#   'toilet paper',
#   'juice',
#   'sugar',
#   'milk',
#   'cereals',
#   'flour',
#   'soda'],
#  ['paper towels',
#   'pork',
#   'cereals',
#   'fruits',
#   'aluminum foil',
#   'bagels',
#   'butter',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'eggs',
#   'lunch meat',
#   'flour',
#   'laundry detergent',
#   'vegetables'],
#  ['butter',
#   'individual meals',
#   'cereals',
#   'toilet paper',
#   'individual meals',
#   'soda',
#   'waffles',
#   'juice',
#   'butter',
#   'sandwich loaves',
#   'individual meals',
#   'yogurt',
#   'soda'],
#  ['ketchup',
#   'flour',
#   'pasta',
#   'soda',
#   'pork',
#   'hand soap',
#   'eggs',
#   'sandwich bags',
#   'soap',
#   'juice',
#   'cheeses',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'lunch meat'],
#  ['cereals',
#   'dinner rolls',
#   'juice',
#   'aluminum foil',
#   'fruits',
#   'spaghetti sauce',
#   'milk',
#   'ice cream',
#   'hand soap',
#   'cheeses',
#   'ketchup',
#   'milk',
#   'lunch meat',
#   'cereals'],
#  ['shampoo',
#   'beef',
#   'sugar',
#   'mixes',
#   'pasta',
#   'toilet paper',
#   'eggs',
#   'dinner rolls',
#   'poultry',
#   'soap',
#   'laundry detergent',
#   'spaghetti sauce',
#   'laundry detergent',
#   'cereals'],
#  ['vegetables',
#   'ice cream',
#   'fruits',
#   'ketchup',
#   'ketchup',
#   'laundry detergent'],
#  ['vegetables',
#   'waffles',
#   'mixes',
#   'vegetables',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'all- purpose',
#   'vegetables',
#   'waffles',
#   'dinner rolls',
#   'sugar',
#   'aluminum foil',
#   'waffles'],
#  ['vegetables',
#   'all- purpose',
#   'coffee/tea',
#   'ketchup',
#   'ketchup',
#   'hand soap',
#   'shampoo',
#   'fruits',
#   'individual meals',
#   'eggs',
#   'sandwich bags',
#   'cheeses',
#   'cereals',
#   'yogurt'],
#  ['toilet paper',
#   'tortillas',
# ...
#   'milk',
#   'all- purpose',
#   'dinner rolls',
#   'coffee/tea',
#   'juice',
#   'dishwashing liquid/detergent',
#   'tortillas'],
#  ['eggs', 'yogurt', 'butter', 'toilet paper', 'eggs', 'waffles'],
#  ['milk',
#   'coffee/tea',
#   'vegetables',
#   'soda',
#   'milk',
#   'individual meals',
#   'sandwich loaves',
#   'pasta',
#   'eggs',
#   'yogurt',
#   'vegetables',
#   'sandwich bags',
#   'vegetables',
#   'milk'],
#  ['cheeses',
#   'vegetables',
#   'cereals',
#   'ice cream',
#   'pork',
#   'waffles',
#   'laundry detergent',
#   'cheeses',
#   'tortillas',
#   'cereals',
#   'all- purpose',
#   'vegetables',
#   'sandwich bags',
#   'soda'],
#  ['toilet paper',
#   'butter',
#   'pork',
#   'juice',
#   'soda',
#   'yogurt',
#   'toilet paper',
#   'sandwich bags',
#   'paper towels',
#   'dinner rolls',
#   'lunch meat',
#   'lunch meat',
#   'pork',
#   'shampoo'],
#  ['flour',
#   'mixes',
#   'all- purpose',
#   'ketchup',
#   'hand soap',
#   'waffles',
#   'sugar',
#   'all- purpose',
#   'soap',
#   'sandwich loaves',
#   'aluminum foil',
#   'cheeses',
#   'toilet paper',
#   'spaghetti sauce'],
#  ['paper towels',
#   'pasta',
#   'ice cream',
#   'spaghetti sauce',
#   'sandwich loaves',
#   'individual meals',
#   'all- purpose',
#   'aluminum foil',
#   'aluminum foil',
#   'toilet paper',
#   'lunch meat'],
#  ['dishwashing liquid/detergent',
#   'soda',
#   'sugar',
#   'milk',
#   'beef',
#   'all- purpose',
#   'paper towels',
#   'toilet paper',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'lunch meat',
#   'all- purpose',
#   'ice cream'],
#  ['ice cream',
#   'shampoo',
#   'pasta',
#   'bagels',
#   'coffee/tea',
#   'waffles',
#   'soda',
#   'dinner rolls',
#   'hand soap',
#   'laundry detergent',
#   'coffee/tea',
#   'eggs',
#   'sugar',
#   'coffee/tea'],
#  ['eggs',
#   'hand soap',
#   'yogurt',
#   'sugar',
#   'vegetables',
#   'sandwich loaves',
#   'all- purpose'],
#  ['ice cream',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'coffee/tea',
#   'milk',
#   'paper towels',
#   'laundry detergent',
#   'poultry',
#   'sandwich bags',
#   'milk',
#   'poultry',
#   'eggs'],
#  ['dishwashing liquid/detergent',
#   'eggs',
#   'cereals',
#   'vegetables',
#   'vegetables',
#   'individual meals',
#   'eggs',
#   'soda',
#   'poultry',
#   'eggs',
#   'tortillas',
#   'tortillas',
#   'toilet paper',
#   'soda'],
#  ['sandwich loaves',
#   'sugar',
#   'dinner rolls',
#   'individual meals',
#   'dinner rolls',
#   'cereals',
#   'spaghetti sauce',
#   'hand soap',
#   'poultry',
#   'waffles',
#   'poultry',
#   'cheeses',
#   'ice cream',
#   'sandwich loaves'],
#  ['soap',
#   'individual meals',
#   'pork',
#   'coffee/tea',
#   'aluminum foil',
#   'cereals',
#   'poultry'],
#  ['eggs',
#   'sandwich loaves',
#   'milk',
#   'lunch meat',
#   'spaghetti sauce',
#   'milk',
#   'ice cream',
#   'all- purpose',
#   'ketchup',
#   'all- purpose',
#   'poultry',
#   'ice cream',
#   'poultry',
#   'dinner rolls'],
#  ['all- purpose',
#   'spaghetti sauce',
#   'dinner rolls',
#   'soda',
#   'juice',
#   'waffles'],
#  ['beef',
#   'spaghetti sauce',
#   'fruits',
#   'poultry',
#   'shampoo',
#   'yogurt',
#   'ice cream',
#   'dinner rolls'],
#  ['paper towels',
#   'pasta',
#   'juice',
#   'milk',
#   'pasta',
#   'hand soap',
#   'mixes',
#   'eggs',
#   'vegetables',
#   'mixes',
#   'dinner rolls',
#   'flour',
#   'pork',
#   'paper towels'],
#  ['individual meals',
#   'sandwich bags',
#   'beef',
#   'poultry',
#   'aluminum foil',
#   'toilet paper',
#   'pork',
#   'cheeses',
#   'dishwashing liquid/detergent',
#   'flour',
#   'pasta',
#   'coffee/tea',
#   'pork',
#   'butter'],
#  ['juice', 'ice cream', 'dishwashing liquid/detergent', 'pasta'],
#  ['paper towels',
#   'aluminum foil',
#   'pork',
#   'soda',
#   'shampoo',
#   'pork',
#   'waffles',
#   'hand soap',
#   'sugar',
#   'sugar',
#   'yogurt',
#   'all- purpose',
#   'pasta',
#   'individual meals'],
#  ['ketchup',
#   'vegetables',
#   'soda',
#   'fruits',
#   'lunch meat',
#   'fruits',
#   'waffles',
#   'cereals',
#   'dinner rolls'],
#  ['soda',
#   'vegetables',
#   'poultry',
#   'vegetables',
#   'sugar',
#   'toilet paper',
#   'vegetables',
#   'toilet paper',
#   'shampoo',
#   'sandwich loaves',
#   'vegetables',
#   'aluminum foil',
#   'pork',
#   'individual meals'],
#  ['cereals',
#   'soap',
#   'cheeses',
#   'individual meals',
#   'flour',
#   'bagels',
#   'all- purpose',
#   'fruits',
#   'bagels',
#   'yogurt',
#   'bagels',
#   'flour',
#   'poultry'],
#  ['laundry detergent',
#   'pork',
#   'yogurt',
#   'vegetables',
#   'fruits',
#   'paper towels',
#   'bagels',
#   'eggs',
#   'waffles',
#   'beef',
#   'individual meals',
#   'paper towels',
#   'vegetables',
#   'cereals'],
#  ['fruits',
#   'hand soap',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'bagels',
#   'flour',
#   'laundry detergent',
#   'aluminum foil',
#   'laundry detergent',
#   'all- purpose'],
#  ['fruits',
#   'beef',
#   'all- purpose',
#   'vegetables',
#   'dinner rolls',
#   'waffles',
#   'vegetables',
#   'individual meals',
#   'dinner rolls',
#   'eggs',
#   'laundry detergent',
#   'pork',
#   'yogurt',
#   'soda'],
#  ['pasta', 'pork', 'flour', 'coffee/tea', 'waffles', 'mixes'],
#  ['toilet paper',
#   'soap',
#   'juice',
#   'toilet paper',
#   'eggs',
#   'beef',
#   'shampoo',
#   'tortillas',
#   'soda',
#   'waffles',
#   'waffles',
#   'eggs',
#   'lunch meat',
#   'spaghetti sauce'],
#  ['ice cream',
#   'sandwich bags',
#   'flour',
#   'juice',
#   'dinner rolls',
#   'coffee/tea',
#   'cheeses',
#   'butter',
#   'vegetables',
#   'aluminum foil',
#   'fruits',
#   'pork',
#   'tortillas',
#   'sandwich loaves'],
#  ['butter',
#   'bagels',
#   'ice cream',
#   'vegetables',
#   'pork',
#   'individual meals',
#   'ice cream',
#   'beef',
#   'aluminum foil',
#   'pork'],
#  ['coffee/tea',
#   'sandwich bags',
#   'ice cream',
#   'sandwich loaves',
#   'paper towels',
#   'fruits',
#   'sandwich bags',
#   'cereals',
#   'mixes',
#   'milk',
#   'paper towels',
#   'tortillas',
#   'yogurt',
#   'individual meals'],
#  ['waffles',
#   'vegetables',
#   'flour',
#   'aluminum foil',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'shampoo',
#   'flour',
#   'spaghetti sauce',
#   'sandwich loaves',
#   'waffles',
#   'yogurt',
#   'sugar',
#   'toilet paper'],
#  ['dinner rolls',
#   'beef',
#   'tortillas',
#   'fruits',
#   'poultry',
#   'beef',
#   'yogurt',
#   'butter',
#   'sugar',
#   'milk',
#   'butter',
#   'sugar',
#   'toilet paper',
#   'cheeses'],
#  ['dishwashing liquid/detergent',
#   'tortillas',
#   'shampoo',
#   'butter',
#   'dishwashing liquid/detergent',
#   'butter',
#   'juice',
#   'beef',
#   'sandwich loaves',
#   'mixes',
#   'paper towels',
#   'vegetables',
#   'soap',
#   'soap'],
#  ['sugar',
#   'dinner rolls',
#   'soap',
#   'toilet paper',
#   'aluminum foil',
#   'butter',
#   'ketchup',
#   'butter',
#   'yogurt',
#   'soda',
#   'juice',
#   'spaghetti sauce',
#   'butter',
#   'soap'],
#  ['lunch meat',
#   'waffles',
#   'flour',
#   'vegetables',
#   'individual meals',
#   'soap',
#   'hand soap',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'soda'],
#  ['vegetables',
#   'laundry detergent',
#   'flour',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'sugar',
#   'pork',
#   'coffee/tea',
#   'individual meals',
#   'ice cream',
#   'soap',
#   'poultry',
#   'all- purpose',
#   'individual meals'],
#  ['pasta',
#   'ice cream',
#   'beef',
#   'toilet paper',
#   'beef',
#   'tortillas',
#   'laundry detergent',
#   'paper towels'],
#  ['vegetables',
#   'dinner rolls',
#   'eggs',
#   'soap',
#   'coffee/tea',
#   'tortillas',
#   'sandwich bags',
#   'sandwich bags',
#   'individual meals',
#   'flour',
#   'vegetables',
#   'fruits',
#   'fruits',
#   'ketchup'],
#  ['laundry detergent',
#   'sandwich bags',
#   'spaghetti sauce',
#   'toilet paper',
#   'aluminum foil',
#   'mixes',
#   'all- purpose',
#   'aluminum foil',
#   'hand soap',
#   'pasta',
#   'juice',
#   'dinner rolls',
#   'ketchup',
#   'eggs'],
#  ['milk',
#   'all- purpose',
#   'vegetables',
#   'vegetables',
#   'flour',
#   'ketchup',
#   'sandwich bags',
#   'cheeses',
#   'laundry detergent',
#   'paper towels',
#   'eggs',
#   'butter',
#   'flour',
#   'sandwich bags'],
#  ['laundry detergent',
#   'sugar',
#   'cheeses',
#   'individual meals',
#   'bagels',
#   'hand soap',
#   'paper towels',
#   'pork',
#   'pork',
#   'waffles',
#   'cheeses',
#   'lunch meat',
#   'tortillas',
#   'dinner rolls'],
#  ['dinner rolls',
#   'tortillas',
#   'ketchup',
#   'tortillas',
#   'sandwich bags',
#   'vegetables',
#   'yogurt',
#   'juice',
#   'fruits',
#   'coffee/tea',
#   'sandwich loaves',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'cereals'],
#  ['sandwich loaves',
#   'hand soap',
#   'soda',
#   'vegetables',
#   'aluminum foil',
#   'toilet paper',
#   'shampoo',
#   'sandwich bags',
#   'paper towels',
#   'shampoo',
#   'vegetables',
#   'ice cream',
#   'sugar',
#   'butter'],
#  ['pasta',
#   'juice',
#   'juice',
#   'mixes',
#   'yogurt',
#   'bagels',
#   'toilet paper',
#   'ice cream'],
#  ['shampoo',
#   'flour',
#   'cheeses',
#   'poultry',
#   'dinner rolls',
#   'fruits',
#   'lunch meat'],
#  ['juice',
#   'cereals',
#   'yogurt',
#   'vegetables',
#   'hand soap',
#   'hand soap',
#   'waffles',
#   'lunch meat',
#   'coffee/tea',
#   'hand soap',
#   'vegetables',
#   'butter',
#   'individual meals',
#   'sandwich loaves'],
#  ['toilet paper',
#   'juice',
#   'flour',
#   'flour',
#   'soap',
#   'vegetables',
#   'eggs',
#   'all- purpose',
#   'pork',
#   'tortillas',
#   'hand soap',
#   'sandwich loaves'],
#  ['milk', 'tortillas', 'milk', 'spaghetti sauce', 'beef', 'poultry', 'fruits'],
#  ['bagels',
#   'toilet paper',
#   'mixes',
#   'spaghetti sauce',
#   'sandwich loaves',
#   'beef',
#   'sandwich bags',
#   'spaghetti sauce',
#   'sugar',
#   'milk',
#   'tortillas',
#   'fruits',
#   'laundry detergent',
#   'spaghetti sauce'],
#  ['yogurt',
#   'milk',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'soap',
#   'poultry',
#   'yogurt',
#   'flour',
#   'soap',
#   'toilet paper',
#   'sugar',
#   'vegetables',
#   'sugar',
#   'cereals'],
#  ['laundry detergent',
#   'pasta',
#   'vegetables',
#   'pork',
#   'yogurt',
#   'yogurt',
#   'flour',
#   'fruits',
#   'sandwich bags',
#   'sandwich bags',
#   'dishwashing liquid/detergent',
#   'flour',
#   'pork',
#   'ice cream'],
#  ['lunch meat', 'sandwich bags', 'waffles', 'soap', 'vegetables', 'fruits'],
#  ['fruits',
#   'yogurt',
#   'cereals',
#   'toilet paper',
#   'dishwashing liquid/detergent',
#   'yogurt',
#   'waffles',
#   'beef',
#   'vegetables',
#   'sugar',
#   'cheeses',
#   'soda',
#   'eggs',
#   'laundry detergent'],
#  ['ice cream', 'sandwich loaves', 'yogurt', 'cereals', 'fruits', 'pasta'],
#  ['ice cream',
#   'pasta',
#   'soap',
#   'waffles',
#   'fruits',
#   'soap',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'paper towels',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'poultry'],
#  ['ketchup',
#   'pasta',
#   'coffee/tea',
#   'shampoo',
#   'poultry',
#   'paper towels',
#   'vegetables',
#   'aluminum foil',
#   'butter',
#   'toilet paper',
#   'soap',
#   'all- purpose',
#   'flour',
#   'soda'],
#  ['vegetables',
#   'soap',
#   'juice',
#   'dinner rolls',
#   'laundry detergent',
#   'aluminum foil',
#   'vegetables',
#   'bagels',
#   'pork',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'tortillas',
#   'cereals',
#   'lunch meat'],
#  ['individual meals',
#   'eggs',
#   'fruits',
#   'pasta',
#   'poultry',
#   'ketchup',
#   'beef',
#   'waffles',
#   'ketchup',
#   'pork',
#   'tortillas',
#   'beef'],
#  ['vegetables',
#   'yogurt',
#   'toilet paper',
#   'soda',
#   'milk',
#   'soap',
#   'sandwich bags',
#   'waffles',
#   'juice',
#   'soda',
#   'yogurt',
#   'cereals',
#   'soap',
#   'pork'],
#  ['paper towels',
#   'tortillas',
#   'juice',
#   'yogurt',
#   'poultry',
#   'individual meals',
#   'lunch meat',
#   'milk',
#   'yogurt',
#   'coffee/tea',
#   'paper towels',
#   'individual meals',
#   'aluminum foil',
#   'paper towels'],
#  ['toilet paper',
#   'yogurt',
#   'butter',
#   'ketchup',
#   'tortillas',
#   'toilet paper',
#   'ice cream',
#   'poultry',
#   'cheeses',
#   'individual meals',
#   'shampoo',
#   'coffee/tea'],
#  ['eggs',
#   'poultry',
#   'soap',
#   'soap',
#   'vegetables',
#   'cereals',
#   'toilet paper',
#   'tortillas',
#   'cereals',
#   'toilet paper',
#   'sandwich loaves',
#   'juice',
#   'all- purpose',
#   'all- purpose'],
#  ['coffee/tea',
#   'fruits',
#   'milk',
#   'vegetables',
#   'waffles',
#   'vegetables',
#   'aluminum foil',
#   'sandwich loaves',
#   'ketchup'],
#  ['eggs',
#   'sandwich loaves',
#   'yogurt',
#   'sandwich loaves',
#   'vegetables',
#   'mixes',
#   'mixes',
#   'poultry',
#   'sugar',
#   'spaghetti sauce',
#   'individual meals',
#   'milk',
#   'butter',
#   'cheeses'],
#  ['aluminum foil',
#   'juice',
#   'flour',
#   'lunch meat',
#   'dinner rolls',
#   'yogurt',
#   'all- purpose',
#   'cereals',
#   'spaghetti sauce',
#   'mixes',
#   'cereals',
#   'butter',
#   'ketchup',
#   'vegetables'],
#  ['soap',
#   'poultry',
#   'ketchup',
#   'juice',
#   'milk',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'ice cream'],
#  ['eggs',
#   'juice',
#   'tortillas',
#   'soda',
#   'fruits',
#   'paper towels',
#   'cheeses',
#   'beef',
#   'pork',
#   'sandwich loaves',
#   'sandwich bags',
#   'paper towels',
#   'aluminum foil',
#   'spaghetti sauce'],
#  ['soda',
#   'beef',
#   'vegetables',
#   'pasta',
#   'yogurt',
#   'paper towels',
#   'toilet paper',
#   'individual meals',
#   'flour',
#   'juice',
#   'dinner rolls',
#   'hand soap',
#   'cheeses',
#   'spaghetti sauce'],
#  ['tortillas',
#   'fruits',
#   'butter',
#   'butter',
#   'mixes',
#   'hand soap',
#   'cheeses',
#   'individual meals',
#   'tortillas',
#   'dishwashing liquid/detergent',
#   'sandwich bags',
#   'bagels'],
#  ['pork',
#   'hand soap',
#   'juice',
#   'vegetables',
#   'ketchup',
#   'toilet paper',
#   'mixes',
#   'mixes',
#   'mixes',
#   'flour',
#   'beef',
#   'pasta'],
#  ['tortillas',
#   'individual meals',
#   'paper towels',
#   'spaghetti sauce',
#   'bagels',
#   'milk',
#   'toilet paper',
#   'butter',
#   'eggs',
#   'ice cream',
#   'tortillas'],
#  ['eggs',
#   'yogurt',
#   'pasta',
#   'beef',
#   'flour',
#   'vegetables',
#   'ketchup',
#   'individual meals'],
#  ['hand soap',
#   'paper towels',
#   'hand soap',
#   'lunch meat',
#   'toilet paper',
#   'milk',
#   'sandwich bags',
#   'individual meals',
#   'cereals',
#   'coffee/tea',
#   'lunch meat'],
#  ['dishwashing liquid/detergent',
#   'soda',
#   'waffles',
#   'lunch meat',
#   'dishwashing liquid/detergent',
#   'pasta',
#   'butter',
#   'dinner rolls',
#   'toilet paper',
#   'mixes',
#   'pork',
#   'yogurt',
#   'bagels'],
#  ['toilet paper',
#   'pasta',
#   'pasta',
#   'laundry detergent',
#   'vegetables',
#   'eggs',
#   'tortillas',
#   'juice',
#   'poultry',
#   'sugar'],
#  ['soap',
#   'sandwich bags',
#   'soap',
#   'vegetables',
#   'eggs',
#   'paper towels',
#   'pork',
#   'ketchup',
#   'tortillas',
#   'waffles',
#   'vegetables',
#   'pork',
#   'coffee/tea',
#   'ketchup'],
#  ['poultry',
#   'pork',
#   'ketchup',
#   'all- purpose',
#   'lunch meat',
#   'ice cream',
#   'all- purpose',
#   'laundry detergent'],
#  ['spaghetti sauce',
#   'lunch meat',
#   'vegetables',
#   'waffles',
#   'butter',
#   'tortillas',
#   'mixes',
#   'ketchup',
#   'eggs',
#   'dinner rolls',
#   'juice',
#   'cheeses',
#   'toilet paper',
#   'toilet paper'],
#  ['spaghetti sauce',
#   'laundry detergent',
#   'vegetables',
#   'fruits',
#   'vegetables',
#   'ketchup',
#   'spaghetti sauce',
#   'aluminum foil',
#   'coffee/tea',
#   'shampoo',
#   'dinner rolls',
#   'vegetables',
#   'pasta',
#   'vegetables'],
#  ['vegetables',
#   'eggs',
#   'spaghetti sauce',
#   'bagels',
#   'mixes',
#   'butter',
#   'poultry',
#   'bagels',
#   'vegetables',
#   'waffles',
#   'sandwich bags',
#   'vegetables',
#   'aluminum foil',
#   'pork'],
#  ['all- purpose',
#   'eggs',
#   'juice',
#   'spaghetti sauce',
#   'juice',
#   'shampoo',
#   'sugar',
#   'hand soap',
#   'waffles',
#   'butter',
#   'juice',
#   'butter',
#   'milk',
#   'dishwashing liquid/detergent'],
#  ['milk',
#   'laundry detergent',
#   'sandwich loaves',
#   'waffles',
#   'eggs',
#   'bagels',
#   'ice cream',
#   'ice cream',
#   'coffee/tea',
#   'tortillas',
#   'sandwich bags',
#   'bagels',
#   'pasta',
#   'all- purpose'],
#  ['spaghetti sauce',
#   'spaghetti sauce',
#   'laundry detergent',
#   'juice',
#   'poultry',
#   'soap',
#   'laundry detergent',
#   'bagels',
#   'all- purpose',
#   'bagels',
#   'hand soap',
#   'fruits',
#   'bagels',
#   'all- purpose'],
#  ['vegetables',
#   'butter',
#   'pasta',
#   'fruits',
#   'all- purpose',
#   'dinner rolls',
#   'sandwich loaves'],
#  ['milk',
#   'toilet paper',
#   'eggs',
#   'pasta',
#   'flour',
#   'pasta',
#   'sandwich bags',
#   'individual meals',
#   'yogurt',
#   'lunch meat',
#   'bagels',
#   'milk',
#   'milk',
#   'aluminum foil'],
#  ['individual meals',
#   'milk',
#   'paper towels',
#   'flour',
#   'lunch meat',
#   'paper towels',
#   'soap',
#   'dishwashing liquid/detergent',
#   'all- purpose',
#   'bagels',
#   'ketchup',
#   'butter',
#   'tortillas',
#   'pork'],
#  ['sandwich bags',
#   'ice cream',
#   'mixes',
#   'paper towels',
#   'pasta',
#   'juice',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'sugar',
#   'individual meals',
#   'tortillas',
#   'pasta',
#   'shampoo'],
#  ...]

# %% [markdown]
# Подготовить данные для обучения.

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder


encoder = TransactionEncoder()
transactions = pd.DataFrame(encoder.fit(basket).transform(basket), columns=encoder.columns_)

transactions.head()
# Out:
#    all- purpose  aluminum foil  bagels   beef  butter  cereals  cheeses  \
# 0          True           True   False   True    True    False    False
# 1         False          False   False  False   False    False     True
# 2         False          False   False  False   False    False    False
# 3          True          False   False  False   False    False    False
# 4         False          False   False  False   False    False    False
#
#    coffee/tea  dinner rolls  dishwashing liquid/detergent  ...  shampoo  \
# 0       False          True                         False  ...     True
# 1       False         False                          True  ...     True
# 2       False          True                         False  ...    False
# 3       False         False                         False  ...    False
# 4       False         False                         False  ...    False
#
#     soap   soda  spaghetti sauce  sugar  toilet paper  tortillas  vegetables  \
# 0  False   True            False  False         False      False        True
# 1  False  False            False  False         False      False        True
# 2   True  False             True  False          True      False       False
# 3  False   True            False  False          True      False       False
# 4  False  False            False  False          True       True        True
#
#    waffles  yogurt
# 0    False   False
# 1     True   False
# 2    False   False
# 3    False   False
# 4    False   False
#
# [5 rows x 38 columns]

# %%
6/len(basket)
# Out:
# 0.004002668445630421

# %%
frequent_itemsets = apriori(transactions, min_support= 4/len(basket), use_colnames=True, max_len =3)
rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = 1.5)
display(rules.head(22))
print("Rules identified: ", len(rules))
# Out:
#                                         antecedents  \
# 0                        (aluminum foil, tortillas)
# 1                                 (sandwich loaves)
# 2                                   (cheeses, beef)
# 3                                   (sandwich bags)
# 4                                     (beef, mixes)
# 5                                            (pork)
# 6                        (sandwich loaves, cheeses)
# 7                                            (soap)
# 8   (spaghetti sauce, dishwashing liquid/detergent)
# 9                                          (fruits)
# 10                            (toilet paper, flour)
# 11                                           (soap)
# 12                                   (juice, mixes)
# 13                                        (ketchup)
# 14                          (sandwich loaves, pork)
# 15                                          (juice)
# 16                        (yogurt, sandwich loaves)
# 17                                          (juice)
# 18                   (tortillas, laundry detergent)
# 19                                        (ketchup)
# 20                           (sandwich bags, mixes)
# 21                                      (tortillas)
#
#                                         consequents  antecedent support  \
# 0                                 (sandwich loaves)            0.058706
# 1                        (aluminum foil, tortillas)            0.248833
# 2                                   (sandwich bags)            0.066711
# 3                                   (cheeses, beef)            0.250167
# 4                                            (pork)            0.065377
# 5                                     (beef, mixes)            0.250167
# 6                                            (soap)            0.064710
# 7                        (sandwich loaves, cheeses)            0.265510
# 8                                          (fruits)            0.061374
# 9   (spaghetti sauce, dishwashing liquid/detergent)            0.263509
# 10                                           (soap)            0.062708
# 11                            (toilet paper, flour)            0.265510
# 12                                        (ketchup)            0.071381
# 13                                   (juice, mixes)            0.250167
# 14                                          (juice)            0.060707
# 15                          (sandwich loaves, pork)            0.257505
# 16                                          (juice)            0.064043
# 17                        (yogurt, sandwich loaves)            0.257505
# 18                                        (ketchup)            0.059373
# 19                   (tortillas, laundry detergent)            0.250167
# 20                                      (tortillas)            0.070714
# 21                           (sandwich bags, mixes)            0.244163
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.248833  0.022015    0.375000  1.507038  0.007407    1.201868
# 1             0.058706  0.022015    0.088472  1.507038  0.007407    1.032655
# 2             0.250167  0.025350    0.380000  1.518987  0.008661    1.209408
# 3             0.066711  0.025350    0.101333  1.518987  0.008661    1.038526
# 4             0.250167  0.025350    0.387755  1.549986  0.008995    1.224728
# 5             0.065377  0.025350    0.101333  1.549986  0.008995    1.040011
# 6             0.265510  0.026017    0.402062  1.514298  0.008836    1.228371
# 7             0.064710  0.026017    0.097990  1.514298  0.008836    1.036896
# 8             0.263509  0.025350    0.413043  1.567474  0.009178    1.254762
# 9             0.061374  0.025350    0.096203  1.567474  0.009178    1.038535
# 10            0.265510  0.025350    0.404255  1.522560  0.008700    1.232893
# 11            0.062708  0.025350    0.095477  1.522560  0.008700    1.036228
# 12            0.250167  0.027352    0.383178  1.531688  0.009494    1.215639
# 13            0.071381  0.027352    0.109333  1.531688  0.009494    1.042611
# 14            0.257505  0.024016    0.395604  1.536298  0.008384    1.228492
# 15            0.060707  0.024016    0.093264  1.536298  0.008384    1.035906
# 16            0.257505  0.026017    0.406250  1.577639  0.009526    1.250518
# 17            0.064043  0.026017    0.101036  1.577639  0.009526    1.041151
# 18            0.250167  0.022682    0.382022  1.527071  0.007829    1.213366
# 19            0.059373  0.022682    0.090667  1.527071  0.007829    1.034414
# 20            0.244163  0.026017    0.367925  1.506882  0.008752    1.195802
# 21            0.070714  0.026017    0.106557  1.506882  0.008752    1.040118
# Rules identified:  22
