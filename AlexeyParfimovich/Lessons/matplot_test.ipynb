# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 4 * np.pi, 100)

plt.figure(figsize=(12,4))
plt.plot(x, x**2, linewidth=2, color='g', dashes=[2,5,2,7])#np.cos(x))
plt.xlabel('x', fontsize=20)
plt.ylabel('y', fontsize=20)
plt.title(r'y = x^2', fontsize=20)
plt.legend(fontsize=20, loc=2)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(100, 2, centers=2, random_state=2, cluster_std=0.1)

X.shape, y.shape

#plt.scatter(X[1:0], y, s=10, cmap='RdBu')

# %%
x = np.linspace(0, 2 * np.pi, 100)

plt.figure(figsize=(12, 6))
plt.plot(x, x**2, linewidth=2, color='g', dashes=[8, 4,8,2], label=r'$\x^2 $')
#plt.axis([0, 2 * np.pi, -1, 1])
# plt.xticks(np.linspace(0, 2 * np.pi, 9),  # Где сделать отметки
#            ('0',r'$\frac{1}{4}\pi$',r'$\frac{1}{2}\pi$',  # Как подписать
#             r'$\frac{3}{4}\pi$',r'$\pi$',r'$\frac{5}{4}\pi$',
#             r'$\frac{3}{2}\pi$',r'$\frac{7}{4}\pi$',r'$2\pi$'),
#            fontsize=22)
#plt.xticks(fontsize=22)
#plt.yticks(fontsize=22)
plt.xlabel('x', fontsize=20)
plt.ylabel('y', fontsize=20)
plt.title(r'y = x^2', fontsize=20)
plt.legend(fontsize=20, loc=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\_mathtext.py:2237, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2236 try:
# -> 2237     result = self._expression.parseString(s)
#    2238 except ParseBaseException as err:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pyparsing\core.py:1141, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1139     else:
#    1140         # catch and re-raise exception from here, clearing out pyparsing internal stack trace
# -> 1141         raise exc.with_traceback(None)
#    1142 else:
#
# ParseFatalException: Unknown symbol: \x, found '\'  (at char 0), (line:1, col:1)
#
# The above exception was the direct cause of the following exception:
#
# ...
