# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import MinMaxScaler as MMScaler

# %%
data_set_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00477/Real%20estate%20valuation%20data%20set.xlsx'

# %%
df = pd.read_excel(data_set_url).set_index('No').drop('X1 transaction date', axis=1)
df
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# No
# 1            32.0                                84.87882
# 2            19.5                               306.59470
# 3            13.3                               561.98450
# 4            13.3                               561.98450
# 5             5.0                               390.56840
# ..            ...                                     ...
# 410          13.7                              4082.01500
# 411           5.6                                90.45606
# 412          18.8                               390.96960
# 413           8.1                               104.81010
# 414           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                 10     24.98298     121.54024
# 2                                  9     24.98034     121.53951
# ...

# %% [markdown]
# # Обрабатываем пропуски и выбросы
# * получаем копию `dataframe` для дальнейших модификаций
# * удаляем все выбросы
# * удаляем пустые значения

# %%
filtered_df = df.loc[:]
filtered_df = filtered_df[(np.abs(stats.zscore(filtered_df)) < 3).all(axis=1)]
filtered_df.dropna(inplace=True)
filtered_df
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# No
# 1            32.0                                84.87882
# 2            19.5                               306.59470
# 3            13.3                               561.98450
# 4            13.3                               561.98450
# 5             5.0                               390.56840
# ..            ...                                     ...
# 410          13.7                              4082.01500
# 411           5.6                                90.45606
# 412          18.8                               390.96960
# 413           8.1                               104.81010
# 414           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                 10     24.98298     121.54024
# 2                                  9     24.98034     121.53951
# ...

# %%
mm_scaler = MMScaler(feature_range=(-1, 1))
filtered_df = mm_scaler.fit_transform(filtered_df)
filtered_df
# Out:
# array([[ 0.46118721, -0.97315973,  1.        ,  0.47394325,  0.26882022,
#         -0.14285714],
#        [-0.10958904, -0.87639056,  0.8       ,  0.39751013,  0.24831461,
#         -0.02121641],
#        [-0.39269406, -0.76492422,  0.        ,  0.60364794,  0.37191011,
#          0.12305516],
#        ...,
#        [-0.14155251, -0.83956465,  0.4       ,  0.36537348,  0.25814607,
#         -0.06647808],
#        [-0.63013699, -0.96446061,  0.        ,  0.00376375,  0.28089888,
#          0.27015559],
#        [-0.70319635, -0.97072551,  0.8       ,  0.22350898,  0.3491573 ,
#          0.59264498]])

# %%
sns.distplot(filtered_df[:], fit=norm, bins = 17);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 sns.distplot(filtered_df[:], fit=norm, bins = 17)
#
# NameError: name 'norm' is not defined
